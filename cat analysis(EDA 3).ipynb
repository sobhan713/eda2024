# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
path=r'E:\data files\\Visadataset.csv'

# %%
vdf=pd.read_csv(path)

# %%
vdf
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
d=dict(vdf.dtypes)
d
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
cls=[keys for keys,value in d.items()]
cls
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cat=[vdf.select_dtypes(include='object').columns]
nu=[vdf.select_dtypes(exclude='object').columns]
nu
# Out:
# [Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')]

# %%
vdf.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %%
vdf.to_csv()
# Out:
# ",case_id,continent,education_of_employee,has_job_experience,requires_job_training,no_of_employees,yr_of_estab,region_of_employment,prevailing_wage,unit_of_wage,full_time_position,case_status\r\n0,EZYV01,Asia,High School,N,N,14513,2007,West,592.2029,Hour,Y,Denied\r\n1,EZYV02,Asia,Master's,Y,N,2412,2002,Northeast,83425.65,Year,Y,Certified\r\n2,EZYV03,Asia,Bachelor's,N,Y,44444,2008,West,122996.86,Year,Y,Denied\r\n3,EZYV04,Asia,Bachelor's,N,N,98,1897,West,83434.03,Year,Y,Denied\r\n4,EZYV05,Africa,Master's,Y,N,1082,2005,South,149907.39,Year,Y,Certified\r\n5,EZYV06,Asia,Master's,Y,N,2339,2012,South,78252.14,Year,Y,Certified\r\n6,EZYV07,Asia,Bachelor's,N,N,4985,1994,South,53635.39,Year,Y,Certified\r\n7,EZYV08,North America,Bachelor's,Y,N,3035,1924,West,418.2298,Hour,Y,Denied\r\n8,EZYV09,Asia,Bachelor's,N,N,4810,2012,Midwest,74362.19,Year,Y,Certified\r\n9,EZYV10,Europe,Doctorate,Y,N,2251,1995,South,67514.76,Year,Y,Certified\r\n10,EZYV11,Asia,Master's,N,N,2465,2004,Midwest,83588.56,Year,Y,Ce
# ...

# %%
vdf['continent']#series method
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
vdf[['continent']]# dataframe type
# Out:
#       continent
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
# ...         ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
#
# [25480 rows x 1 columns]

# %%
vdf.continent
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %% [markdown]
# read multiple columns
#
# - whenever we see multiple means recall the list
#
# - keep the name of the columns in a list
#
# - pass the list

# %%
c=['continent','education_of_employee']
vdf[c]
# Out:
#       continent education_of_employee
# 0          Asia           High School
# 1          Asia              Master's
# 2          Asia            Bachelor's
# 3          Asia            Bachelor's
# 4        Africa              Master's
# ...         ...                   ...
# 25475      Asia            Bachelor's
# 25476      Asia           High School
# 25477      Asia              Master's
# 25478      Asia              Master's
# 25479      Asia            Bachelor's
#
# [25480 rows x 2 columns]

# %% [markdown]
# $task 1$
#
# **we want to find the no of applicants continent wise**
#
# $**unique  method**$
#
#     -it will provide how many unique items are their in a particular column

# %%
ct=vdf['continent'].unique()
ct
# Out:
# array(['Asia', 'Africa', 'North America', 'Europe', 'South America',
#        'Oceania'], dtype=object)

# %% [markdown]
# **nunique method**
#
# - gives count of unique no

# %%
vdf['continent'].nunique()
# Out:
# 6

# %%
con=vdf['continent']=='Asia'
con
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 25475     True
# 25476     True
# 25477     True
# 25478     True
# 25479     True
# Name: continent, Length: 25480, dtype: bool

# %% [markdown]
# step 1= read the data with specific column
#
# step2= apply the condition
#
#         when we apply the condition python will give t aand f
#
# step3= to retrive the true data

# %%
len(vdf[con])
# Out:
# 16861

# %%
con=vdf['continent']=='Europe'
len(vdf[con])
#vdf[con]
# Out:
# 3732

# %%
for i in vdf['continent'].unique():
    con=vdf['continent']==i
    c=len(vdf[con])
    print(f'{i}  {c}')
# Out:
# Asia  16861
# Africa  551
# North America  3292
# Europe  3732
# South America  852
# Oceania  192

# %%
ct=vdf['continent'].unique()
cou=[]
for i in vdf['continent'].unique():
    con=vdf['continent']==i
    cou.append(len(vdf[con]))
    
cols=['continent','no of applicants']
d=pd.DataFrame(zip(ct,cou),columns=cols)
d.to_csv('v1.csv', index=False)

# %%
cdf=vdf['continent'].value_counts()
cdf
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %% [markdown]
# **30/07/24**

# %% [markdown]
# - we created a dataframe of unique values of a columns and its count
#
# - we created by our own way , by using for loop
#
# - we can use value_count method for that

# %%
dir(cdf)
# Out:
# ['Africa',
#  'Asia',
#  'Europe',
#  'Oceania',
#  'T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__column_consortium_standard__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
# ...

# %%
type(cdf)
# Out:
# pandas.core.series.Series

# %%
keys=cdf.keys()
keys
# Out:
# Index(['Asia', 'Europe', 'North America', 'South America', 'Africa',
#        'Oceania'],
#       dtype='object', name='continent')

# %%
values=cdf.values

# %%
cdf=vdf['continent'].value_counts()
values=cdf.values
keys=cdf.keys()
cols=['label','count']
df=pd.DataFrame(zip(keys,values),columns=cols)
df
# Out:
#            label  count
# 0           Asia  16861
# 1         Europe   3732
# 2  North America   3292
# 3  South America    852
# 4         Africa    551
# 5        Oceania    192

# %%
cdf=vdf['education_of_employee'].value_counts()
values=cdf.values
keys=cdf.keys()
cols=['label','count']
df=pd.DataFrame(zip(keys,values),columns=cols)
df
# Out:
#          label  count
# 0   Bachelor's  10234
# 1     Master's   9634
# 2  High School   3420
# 3    Doctorate   2192

# %%
dict(vdf.dtypes)
cat=[keys for keys,values in dict(vdf.dtypes).items() if values=='object']
cat
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
dict(vdf.dtypes)
cat=[keys for keys,values in dict(vdf.dtypes).items() if values=='object']
for i in cat:
    cdf=vdf[i].value_counts()
    values=cdf.values
    keys=cdf.keys()
    cols=['label','count']
    df=pd.DataFrame(zip(keys,values),columns=cols)
    path=r'E:\datascience\vdf'
    df.to_csv(f'{path}\\{i}.csv',index=False)
    df

# %% [markdown]
# **normalize**
#
# - relative frequency table
#
# - will give percentage of labels in columns

# %%
cdf=vdf['continent'].value_counts(normalize=True)
cdf
# Out:
# continent
# Asia             0.661735
# Europe           0.146468
# North America    0.129199
# South America    0.033438
# Africa           0.021625
# Oceania          0.007535
# Name: proportion, dtype: float64

# %% [markdown]
# **bar chart**
#
# - it is the graphical representation of frequency table
#
# - bar graph is a plot beyween count and class
#
# -in order to pllot we required two columns
#
#     - cat
#
#     - num
#
# - we have already created a **continent.csv**
#
#     - here we have cols=['continents','number_of_applicants']
#
#     - cat column is **continents**
#
#     - numerical columns is **number_of_applicants**
#
# - package is mathpotlib

# %%
import matplotlib.pyplot as plt
plt.bar('continent','no of applicants',data=d)
plt.title('con')
plt.xlabel('continents')
plt.ylabel('number of applicants')
plt.savefig(f'continent barchart.jpg')

# %%
for i in cat[1:]:
    cdf=vdf[i].value_counts()
    values=cdf.values
    keys=cdf.keys()
    cols=['label','count']
    df=pd.DataFrame(zip(keys,values),columns=cols)
    plt.figure(figsize=(8,3))
    plt.bar(df['label'],df['count'],width=0.5)
    plt.title(i)
    plt.xlabel('lable')
    plt.ylabel('count')
    plt.show()
