# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# - here we are reading visa dataset
#
# - which is a csv type
#
# - it is located in data science folder
#
# - inorder to read any dataset
#
#     - directory
#
#     - filename
#
#     - type

# %%
path='E:\data files\\Visadataset.csv'

# %%
visa_df=pd.read_csv(path)

# %%
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
path1=r"E:\data files\bank.csv"

# %%
bank_df=pd.read_csv(path1,sep=';')

# %%
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
df_sorted = visa_df.sort_values(by=['continent','education_of_employee'], ascending=[True, False])

# %%
df_sorted
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 4         EZYV05         Africa              Master's                  Y
# 18        EZYV19         Africa              Master's                  Y
# 74        EZYV75         Africa              Master's                  Y
# 194      EZYV195         Africa              Master's                  Y
# 273      EZYV274         Africa              Master's                  N
# ...          ...            ...                   ...                ...
# 25180  EZYV25181  South America            Bachelor's                  N
# 25252  EZYV25253  South America            Bachelor's                  Y
# 25300  EZYV25301  South America            Bachelor's                  N
# 25364  EZYV25365  South America            Bachelor's                  Y
# 25455  EZYV25456  South America            Bachelor's                  N
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# ...

# %%
dir(visa_df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
visa_df.head(n=9)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# ...

# %%
tail

shape

size

columns

dtypes

info

take

loc

isnum

# %%
visa_df.tail(20)
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25460  EZYV25461         Europe              Master's                  Y
# 25461  EZYV25462           Asia              Master's                  Y
# 25462  EZYV25463         Europe            Bachelor's                  N
# 25463  EZYV25464           Asia           High School                  N
# 25464  EZYV25465           Asia              Master's                  N
# 25465  EZYV25466  North America           High School                  N
# 25466  EZYV25467         Europe            Bachelor's                  Y
# 25467  EZYV25468  North America              Master's                  N
# 25468  EZYV25469           Asia            Bachelor's                  N
# 25469  EZYV25470  North America              Master's                  Y
# 25470  EZYV25471  North America              Master's                  Y
# 25471  EZYV25472           Asia           High School                  N
# ...

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
visa_df.size
# Out:
# 305760

# %%
visa_df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
** dtype always gives in series**
# Out:
#   Cell In[17], line 1
#     ** dtype always gives in series**
#     ^
# SyntaxError: invalid syntax

# %%
type(visa_df.dtypes)

# %%
**task 1**

- i want to crete two list

- one is categorical other is numerical

-usig dtypes

# %%
- convert series into dictionary

-  iterate through dictionary

# %%
dict(visa_df.dtypes)

# %%
keys_list = [key for key in visa_df.keys()]

# %%
keys_list

# %%
num_l=[]
cat_l=[]
df=dict(visa_df.dtypes)
for i,j in df.items():
    if j=='object':
        cat_l.append(i)
    else:
        num_l.append(i)
print(num_l)
print(cat_l)

# %%
cat_l=[i for i,j in df.items() if j=='object']
cat_l

# %%
data=dict(visa_df.dtypes)
cat=[i for i,j in data.items() if j=='object']
num=[i for i,j in data.items() if j!='object']
print(num, cat)
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage'] ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']

# %%
num_l=[]
cat_l=[]
df=dict(visa_df.dtypes)
for i,j in df.items():
    if j=='object':
        cat_l.append(i)
    else:
        num_l.append(i)
print(num_l)
print(cat_l)
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status']

# %%
len(num_l),len(cat_l)
# Out:
# (3, 9)

# %% [markdown]
# ** we cant create a dataframe using the above two list as they are un equal in length
#
# - if want to create a dataframe ,then we need to make two list of equal length
#
#     - how can we mak ethe list of equa length
#
#     - haw can we do that**

# %% [markdown]
# **create columns dataframe**

# %%
ca=pd.DataFrame(cat_l,columns=['cat col'])
nu=pd.DataFrame(num_l,columns=['num col'])
nu.to_csv('numerical_column.csv',index=False)
ca.to_csv('categorical_column.csv',index=False)

# %%
pd.read_csv('numerical_column.csv')
# Out:
#            num col
# 0  no_of_employees
# 1      yr_of_estab
# 2  prevailing_wage

# %%
**task 2**

- create 2 list

# %%
cols=[]
data=[]
df=dict(visa_df.dtypes)
cols=[keys for keys,values in df.items()]
data=[values for keys,values in df.items()]
d=zip(cols,data)
df3=pd.DataFrame(d,columns=['cols','datatype'])
df3
# Out:
#                      cols datatype
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
**task 3**

- **we can create a dataframe using dictionary also**

- advantage is no need to provide column name as keys behaves as column names

# %%
dic1={'names':['ak','sk','dm'],'age':[20,24,25]}
dic1
# Out:
# {'names': ['ak', 'sk', 'dm'], 'age': [20, 24, 25]}

# %%
pd.DataFrame(dic1)
# Out:
#   names  age
# 0    ak   20
# 1    sk   24
# 2    dm   25

# %%
# d2=dict(zip(cols,data))
# # df3=pd.DataFrame(d2)
# # df3
# d2
d={}
d['columns']=cols
d['data']=data
df3=pd.DataFrame(d)
df3
# Out:
#                   columns     data
# 0                 case_id   object
# 1               continent   object
# 2   education_of_employee   object
# 3      has_job_experience   object
# 4   requires_job_training   object
# 5         no_of_employees    int64
# 6             yr_of_estab    int64
# 7    region_of_employment   object
# 8         prevailing_wage  float64
# 9            unit_of_wage   object
# 10     full_time_position   object
# 11            case_status   object

# %%
cat_l
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
visa_df.select_dtypes()

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# **task 3**
#
# - list to dataframe
#
# - dict to df
#
# - list to dict to df
#
# - dict to list to df

# %%
**is null**

- element is missed

- missing values

-we are asking a  question if any element is missed or not

- then com will give true or false

-true= value missed

# %%
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...
