# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# - it is a 360 degree view
#
# - takes keys and values
#
# - that will get from value counts

# %% [markdown]
# ste1 - get keys from continent value counts
#
# step2 - get values fron continent value count
#
# step3 - plt.pie verify the argue ment

# %%
path=r'E:\data files\\Visadataset.csv'
vdf=pd.read_csv(path)

# %%
cat=[keys for keys,values in dict(vdf.dtypes).items() if values=='object']
num=[keys for keys,values in dict(vdf.dtypes).items() if values!='object']

# %%
vdf['continent'].value_counts()
# Out:
# continent
# Asia             16861
# Europe            3732
# North America     3292
# South America      852
# Africa             551
# Oceania            192
# Name: count, dtype: int64

# %%
keys=vdf['continent'].value_counts().keys()
values=vdf['continent'].value_counts().values
plt.pie(values, explode=[0.1,0.2,0.3,0.4,1.5,1]
        ,labels=keys,autopct='%0.2f%%',radius=3
       ,startangle=120)
plt.show()
